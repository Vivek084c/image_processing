# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model


def conv_block(inputs, num_filters):
    """
    num_filters: define the number of channels in the output feature map, generally it is equall to the number of classes
    """

    #1st layer is convolution layer with 3*3 kernal size and padding="same" i.e the output feature map will be same as input feature map, here inputs is the input image
    x=Conv2D(num_filters, 3, padding="same")(inputs)
    x=BatchNormalization()(x)
    x=Activation("relu")(x)

    x=Conv2D(num_filters, 3, padding="same")(x)
    x=BatchNormalization()(x)
    x=Activation("relu")(x)

    return x


def encoder_block(inputs, num_filters):
    x=conv_block(inputs, num_filters)
    p=MaxPool2D((2, 2))(x) # the height and width of feature map will reduce to half
    return x,p #we return two output as we need to have some skip connections


def decoder_block(inputs,skip_connection, num_filters):
    x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(inputs) #strides=2 signifies that the output feature map will be twice the input
    x = Concatenate()([x, skip_connection])
    x = conv_block(x, num_filters)
    return x

def Unet(input_shape, number_of_classes):
    inputs=Input(input_shape)

    #we call the encoder block
    skip_connection_1, pooling_block_1=encoder_block(inputs, num_filters=64)
    skip_connection_2, pooling_block_2=encoder_block(pooling_block_1, num_filters=128)
    skip_connection_3, pooling_block_3=encoder_block(pooling_block_2, num_filters=256)
    skip_connection_4, pooling_block_4=encoder_block(pooling_block_3, num_filters=512)

    #defining the bridge block between the encoder and decoder block
    bridge_block_1=conv_block(pooling_block_4, num_filters=1024 )


    #calling the decoder block
    decoder_1=decoder_block(bridge_block_1, skip_connection_4, 512)
    decoder_2=decoder_block(decoder_1, skip_connection_3, 256)
    decoder_3=decoder_block(decoder_2, skip_connection_2, 128)
    decoder_4=decoder_block(decoder_3, skip_connection_1, 64)
    print(decoder_4.shape)

    #defining the output layer
    output=Conv2D(number_of_classes, 1, padding="same", activation="softmax")(decoder_4)
    model=Model(inputs, output)
    return model

# %%
input_shape=(256, 256, 3)
model = Unet(input_shape, 20)
model.summary()
# Out:
# (None, 256, 256, 64)
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_145 (Conv2D)            (None, 256, 256, 64  1792        ['input_11[0][0]']
#                                 )
#
#  batch_normalization_142 (Batch  (None, 256, 256, 64  256        ['conv2d_145[0][0]']
#  Normalization)                 )
#
#  activation_142 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_142[0][0]']
#                                 )
#
#  conv2d_146 (Conv2D)            (None, 256, 256, 64  36928       ['activation_142[0][0]']
#                                 )
#
#  batch_normalization_143 (Batch  (None, 256, 256, 64  256        ['conv2d_146[0][0]']
#  Normalization)                 )
#
#  activation_143 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_143[0][0]']
#                                 )
#
#  max_pooling2d_40 (MaxPooling2D  (None, 128, 128, 64  0          ['activation_143[0][0]']
#  )                              )
#
#  conv2d_147 (Conv2D)            (None, 128, 128, 12  73856       ['max_pooling2d_40[0][0]']
#                                 8)
#
#  batch_normalization_144 (Batch  (None, 128, 128, 12  512        ['conv2d_147[0][0]']
#  Normalization)                 8)
#
#  activation_144 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_144[0][0]']
#                                 8)
#
#  conv2d_148 (Conv2D)            (None, 128, 128, 12  147584      ['activation_144[0][0]']
#                                 8)
#
#  batch_normalization_145 (Batch  (None, 128, 128, 12  512        ['conv2d_148[0][0]']
#  Normalization)                 8)
#
#  activation_145 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_145[0][0]']
#                                 8)
#
#  max_pooling2d_41 (MaxPooling2D  (None, 64, 64, 128)  0          ['activation_145[0][0]']
#  )
#
#  conv2d_149 (Conv2D)            (None, 64, 64, 256)  295168      ['max_pooling2d_41[0][0]']
#
#  batch_normalization_146 (Batch  (None, 64, 64, 256)  1024       ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 64, 64, 256)  590080      ['activation_146[0][0]']
#
#  batch_normalization_147 (Batch  (None, 64, 64, 256)  1024       ['conv2d_150[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_147[0][0]']
#
#  max_pooling2d_42 (MaxPooling2D  (None, 32, 32, 256)  0          ['activation_147[0][0]']
#  )
#
#  conv2d_151 (Conv2D)            (None, 32, 32, 512)  1180160     ['max_pooling2d_42[0][0]']
#
#  batch_normalization_148 (Batch  (None, 32, 32, 512)  2048       ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 32, 32, 512)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 32, 32, 512)  2359808     ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 32, 32, 512)  2048       ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 32, 32, 512)  0           ['batch_normalization_149[0][0]']
#
#  max_pooling2d_43 (MaxPooling2D  (None, 16, 16, 512)  0          ['activation_149[0][0]']
#  )
#
#  conv2d_153 (Conv2D)            (None, 16, 16, 1024  4719616     ['max_pooling2d_43[0][0]']
#                                 )
#
#  batch_normalization_150 (Batch  (None, 16, 16, 1024  4096       ['conv2d_153[0][0]']
#  Normalization)                 )
#
#  activation_150 (Activation)    (None, 16, 16, 1024  0           ['batch_normalization_150[0][0]']
#                                 )
#
#  conv2d_154 (Conv2D)            (None, 16, 16, 1024  9438208     ['activation_150[0][0]']
#                                 )
#
#  batch_normalization_151 (Batch  (None, 16, 16, 1024  4096       ['conv2d_154[0][0]']
#  Normalization)                 )
#
#  activation_151 (Activation)    (None, 16, 16, 1024  0           ['batch_normalization_151[0][0]']
#                                 )
#
#  conv2d_transpose_22 (Conv2DTra  (None, 32, 32, 512)  2097664    ['activation_151[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_transpose_22[0][0]',
#                                 )                                 'activation_149[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 32, 32, 512)  4719104     ['concatenate_21[0][0]']
#
#  batch_normalization_152 (Batch  (None, 32, 32, 512)  2048       ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 32, 32, 512)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 32, 32, 512)  2359808     ['activation_152[0][0]']
#
#  batch_normalization_153 (Batch  (None, 32, 32, 512)  2048       ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 32, 32, 512)  0           ['batch_normalization_153[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 64, 64, 256)  524544     ['activation_153[0][0]']
#  nspose)
#
#  concatenate_22 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_23[0][0]',
#                                                                   'activation_147[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 64, 64, 256)  1179904     ['concatenate_22[0][0]']
#
#  batch_normalization_154 (Batch  (None, 64, 64, 256)  1024       ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_154[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 64, 64, 256)  590080      ['activation_154[0][0]']
#
#  batch_normalization_155 (Batch  (None, 64, 64, 256)  1024       ['conv2d_158[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 64, 64, 256)  0           ['batch_normalization_155[0][0]']
#
#  conv2d_transpose_24 (Conv2DTra  (None, 128, 128, 12  131200     ['activation_155[0][0]']
#  nspose)                        8)
#
#  concatenate_23 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_24[0][0]',
#                                 6)                                'activation_145[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 128, 128, 12  295040      ['concatenate_23[0][0]']
#                                 8)
#
#  batch_normalization_156 (Batch  (None, 128, 128, 12  512        ['conv2d_159[0][0]']
#  Normalization)                 8)
#
#  activation_156 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_156[0][0]']
#                                 8)
#
#  conv2d_160 (Conv2D)            (None, 128, 128, 12  147584      ['activation_156[0][0]']
#                                 8)
#
#  batch_normalization_157 (Batch  (None, 128, 128, 12  512        ['conv2d_160[0][0]']
#  Normalization)                 8)
#
#  activation_157 (Activation)    (None, 128, 128, 12  0           ['batch_normalization_157[0][0]']
#                                 8)
#
#  conv2d_transpose_25 (Conv2DTra  (None, 256, 256, 64  32832      ['activation_157[0][0]']
#  nspose)                        )
#
#  concatenate_24 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_25[0][0]',
#                                 8)                                'activation_143[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 256, 256, 64  73792       ['concatenate_24[0][0]']
#                                 )
#
#  batch_normalization_158 (Batch  (None, 256, 256, 64  256        ['conv2d_161[0][0]']
#  Normalization)                 )
#
#  activation_158 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_158[0][0]']
#                                 )
#
#  conv2d_162 (Conv2D)            (None, 256, 256, 64  36928       ['activation_158[0][0]']
#                                 )
#
#  batch_normalization_159 (Batch  (None, 256, 256, 64  256        ['conv2d_162[0][0]']
#  Normalization)                 )
#
#  activation_159 (Activation)    (None, 256, 256, 64  0           ['batch_normalization_159[0][0]']
#                                 )
#
#  conv2d_163 (Conv2D)            (None, 256, 256, 20  1300        ['activation_159[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 31,056,532
# Trainable params: 31,044,756
# Non-trainable params: 11,776
# __________________________________________________________________________________________________
